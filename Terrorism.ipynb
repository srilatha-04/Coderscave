# %%
#importing the packages
import pandas as pd

# %%
#reading the dataset
df=pd.read_csv("globalterrorism.csv",low_memory=False)
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
#printing the last 5 rows of the dataset
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#printing the first 5 rows of the dataset
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#describing the shape of the dataset
df.shape
# Out:
# (181691, 135)

# %%
#describing the dataset
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#describing the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#describing the null values in dataset
df.isnull()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
#sum of the null values through columns of dataset
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#describing the datatypes of the columns in dataset
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
#removing the null columns
df.drop('extended',axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ... addnotes  \
# ...

# %%
#removing the null columns
df.drop("related",axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#removing the null columns
df.drop("addnotes",axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#removing the null columns
df.drop("hostkidoutcome_txt",axis=1,inplace=True)
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#removing the null columns
df.drop('hostkidoutcome',axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#counting the values 
df.country	.value_counts()
# Out:
# 95     24636
# 153    14368
# 4      12731
# 92     11960
# 45      8306
#        ...
# 428        1
# 221        1
# 10         1
# 7          1
# 226        1
# Name: country, Length: 205, dtype: int64

# %%
#counting the values 
df.country_txt.value_counts()
# Out:
# Iraq                 24636
# Pakistan             14368
# Afghanistan          12731
# India                11960
# Colombia              8306
#                      ...
# Andorra                  1
# St. Lucia                1
# South Vietnam            1
# Wallis and Futuna        1
# Vatican City             1
# Name: country_txt, Length: 205, dtype: int64

# %%
#counting the values 
df.provstate.value_counts()
# Out:
# Baghdad                   7645
# Northern Ireland          4498
# Unknown                   4290
# Balochistan               3710
# Saladin                   3411
#                           ...
# Lipkovo (Municipality)       1
# Yamaguchi                    1
# El Tarf                      1
# Kumamoto                     1
# Savanes                      1
# Name: provstate, Length: 2854, dtype: int64

# %%
#filling null values
df["ransomnote"].fillna("scite1",inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
import numpy as np
#replacing the nan values with the mode of scite1 in scite2
mode=df["scite1"].mode().values[0]
df["scite2"]=df["scite1"].replace(np.nan,mode)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#replacing the nan values with the mode of scite2 in scite1
mode=df["scite2"].mode().values[0]
df["scite1"]=df["scite1"].replace(np.nan,mode)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#replacing the nan values with mode of scite3
mode=df["scite3"].mode().values[0]
df["scite3"]=df["scite3"].replace(np.nan,mode)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#removing the nreleased column of dataset
df.drop("nreleased",axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#eliminating the ransompaidus coulmn from dataset
df.drop("ransompaidus",axis=1,inplace=True)

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate resolution  country  \
# 0       197000000001   1970       7     2        NaN        NaN       58
# 1       197000000002   1970       0     0        NaN        NaN      130
# 2       197001000001   1970       1     0        NaN        NaN      160
# 3       197001000002   1970       1     0        NaN        NaN       78
# 4       197001000003   1970       1     0        NaN        NaN      101
# ...              ...    ...     ...   ...        ...        ...      ...
# 181686  201712310022   2017      12    31        NaN        NaN      182
# 181687  201712310029   2017      12    31        NaN        NaN      200
# 181688  201712310030   2017      12    31        NaN        NaN      160
# 181689  201712310031   2017      12    31        NaN        NaN       92
# 181690  201712310032   2017      12    31        NaN        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# ...

# %%
#defining the mean for eventid
df_mean=df.eventid.mean()
print("Eventid:",df_mean)
# Out:
# Eventid: 200270523949.02155

# %%
#defing the Median for evenid
df_median=df.eventid.median()
print("meadian:",df_median)
# Out:
# meadian: 200902230001.0

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Histogram

# %%
#importing the packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#histogram based on iyear
sns.histplot(x='iyear', data=df, )
plt.show()

# %%
#histogram based on imonth
sns.histplot(x='imonth', data=df, )
plt.show()

# %%
#histogram based on iday
sns.histplot(x='iday', data=df, )
plt.show()

# %%
#histogram based on region
sns.histplot(x='region', data=df, )
plt.show()

# %%
#histogram based on INT_LOG
sns.histplot(x='INT_LOG', data=df, )
plt.show()

# %%
#histogram based on INT_IDEO 
sns.histplot(x='INT_IDEO', data=df, )
plt.show()

# %%
#histogram on INT_MISC
sns.histplot(x='INT_MISC', data=df, )
plt.show()

# %%
#histogram based on INT_ANY
sns.histplot(x='INT_ANY', data=df, )
plt.show()

# %% [markdown]
# ## BoxPlot

# %%
#importing the packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Boxplot between INT_MISC and INT_LOG
sns.boxplot( x="INT_MISC", y='INT_LOG', data=df, )
plt.show()

# %%
#Boxplot between INT_MISC and INT_ANY
sns.boxplot( x="INT_MISC", y='INT_ANY', data=df, )
plt.show()

# %%
#Boxplot between INT_LOG and iyear
sns.boxplot( x="INT_LOG", y='iyear', data=df, )
plt.show()

# %%
#Boxplot between INT_LOG and imonth
sns.boxplot( x="INT_LOG", y='imonth', data=df, )
plt.show()

# %%
#Boxplot between INT_LOG and iday
sns.boxplot( x="INT_LOG", y='iday', data=df, )
plt.show()

# %%
#Boxplot between INT_ANY and iyear
sns.boxplot( x="INT_ANY", y='iyear', data=df, )
plt.show()

# %%
#Boxplot between INT_ANY and imonth
sns.boxplot( x="INT_ANY", y='imonth', data=df, )
plt.show()

# %%
#Boxplot between INT_ANY and iday
sns.boxplot( x="INT_ANY", y='iday', data=df, )
plt.show()

# %% [markdown]
# ## Scatter Boxplot For Data Visualization

# %%
#importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#scatter boxplot between evenitid and iyear
sns.scatterplot( x="eventid", y='iyear', data=df,
                hue='country')
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
#scatter Box plot between eventid and imonth
sns.scatterplot( x="eventid", y='imonth', data=df,
                hue='country')
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
#scatter boxplot between eventid and iday
sns.scatterplot( x="eventid", y='iday', data=df,
                hue='country')
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %%
sns.scatterplot( x="region", y='dbsource', data=df,
                hue='country')
 
# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)
 
plt.show()

# %% [markdown]
# ## Barplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#barplot between INT_LOG and iyear
sns.barplot(x="INT_LOG",y="iyear",data=df)
plt.show()

# %%
#barplot between INT_ANY and iyear
sns.barplot(x="INT_ANY",y="iyear",data=df)
plt.show()

# %%
#barplot between INT_LOG and iyear
sns.barplot(x="INT_LOG",y="iyear",hue="country",data=df)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#scatterplot between imonth and iyear
d1=df.loc[df.region==6,:]
x=df["imonth"]
y=df["iyear"]
sns.scatterplot(x=x,y=y,data=d1)
# Out:
# <AxesSubplot:xlabel='imonth', ylabel='iyear'>

# %%
x="region"
y="iyear"

# %%
#scatterplot between region and iyear
sns.scatterplot(x=x,y=y,data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='iyear'>

# %%
#scatterplot between INT_LOG and INT_MISC
import seaborn as sns
import matplotlib.pyplot as plt

x = "INT_LOG"
y = "INT_MISC"

sns.scatterplot(x=x, y=y, data=df)
plt.show()  # This line is important to display the plot

# %%
#scatterplot for INT_LOG AND INT_IDEO
import seaborn as sns
import matplotlib.pyplot as plt

x = "INT_LOG"
y = "INT_IDEO"

sns.scatterplot(x=x, y=y, data=df)
plt.show()

# %% [markdown]
# ## Stackplot

# %%
#scatter plot based on region,INT_LOG and country
x=df["region"]
y=df["INT_LOG"]
z=df["country"]
plt.xlabel("country")
plt.ylabel("int_log")
plt.stackplot(x,y,z,colors=['r','g','b'],baseline='zero')
plt.show()
