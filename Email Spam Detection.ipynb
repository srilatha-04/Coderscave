# %%
#importing the libraries
import pandas as pd

# %%
#reading the dataset
df=pd.read_csv("spam.csv")

# %%
df
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
#Information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
#describing about the dataset
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# ...

# %%
#counting the no.of rows for each columns in dataset
df.count()
# Out:
# word_freq_make                4601
# word_freq_address             4601
# word_freq_all                 4601
# word_freq_3d                  4601
# word_freq_our                 4601
# word_freq_over                4601
# word_freq_remove              4601
# word_freq_internet            4601
# word_freq_order               4601
# word_freq_mail                4601
# word_freq_receive             4601
# word_freq_will                4601
# word_freq_people              4601
# word_freq_report              4601
# word_freq_addresses           4601
# word_freq_free                4601
# word_freq_business            4601
# word_freq_email               4601
# word_freq_you                 4601
# word_freq_credit              4601
# word_freq_your                4601
# word_freq_font                4601
# word_freq_000                 4601
# word_freq_money               4601
# word_freq_hp                  4601
# word_freq_hpl                 4601
# word_freq_george              4601
# ...

# %%
#describing the columns of the dataset
df.columns
# Out:
# Index(['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d',
#        'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
# ...

# %%
#type of the dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#length of dataset
len(df)
# Out:
# 4601

# %%
#describig whether dataset consit of null's
df.isnull()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0              False              False          False         False
# 1              False              False          False         False
# 2              False              False          False         False
# 3              False              False          False         False
# 4              False              False          False         False
# ...              ...                ...            ...           ...
# 4596           False              False          False         False
# 4597           False              False          False         False
# 4598           False              False          False         False
# 4599           False              False          False         False
# 4600           False              False          False         False
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
#describing the shape of datset
df.shape
# Out:
# (4601, 58)

# %%
#displaying the Last 5 rows of the dataset
df.tail()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4596            0.31                0.0           0.62           0.0
# 4597            0.00                0.0           0.00           0.0
# 4598            0.30                0.0           0.30           0.0
# 4599            0.96                0.0           0.00           0.0
# 4600            0.00                0.0           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4596           0.00            0.31               0.0                 0.0
# 4597           0.00            0.00               0.0                 0.0
# 4598           0.00            0.00               0.0                 0.0
# 4599           0.32            0.00               0.0                 0.0
# 4600           0.00            0.00               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# ...

# %%
#displaying the first 5 rows of the dataset
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
#importing the library
import numpy as np

# %%
#percentage of the capital_run_length_average
np.percentile(df["capital_run_length_average"],30,axis=0)
# Out:
# 1.714

# %%
#percentage of the char_freq_$
np.percentile(df["char_freq_$"],40,axis=0)
# Out:
# 0.0

# %%
#percentage of the word_freq_people
np.percentile(df["word_freq_people"],30,axis=0)
# Out:
# 0.0

# %%
#percentage of capital_run_length_longest
np.percentile(df["capital_run_length_longest"],30,axis=0)
# Out:
# 8.0

# %% [markdown]
# ### filtering the data set

# %%
df["capital_run_length_longest"].isin([40])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# 4600    False
# Name: capital_run_length_longest, Length: 4601, dtype: bool

# %%
df["word_freq_address"].isin([0.0])
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4596     True
# 4597     True
# 4598     True
# 4599     True
# 4600     True
# Name: word_freq_address, Length: 4601, dtype: bool

# %%
df["word_freq_all"].isin([0.0])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 4596    False
# 4597     True
# 4598    False
# 4599     True
# 4600    False
# Name: word_freq_all, Length: 4601, dtype: bool

# %%
df["word_freq_internet"].isin([0.0])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4596     True
# 4597     True
# 4598     True
# 4599     True
# 4600     True
# Name: word_freq_internet, Length: 4601, dtype: bool

# %%
#displaying the columns that are notnull
df.notnull()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               True               True           True          True
# 1               True               True           True          True
# 2               True               True           True          True
# 3               True               True           True          True
# 4               True               True           True          True
# ...              ...                ...            ...           ...
# 4596            True               True           True          True
# 4597            True               True           True          True
# 4598            True               True           True          True
# 4599            True               True           True          True
# 4600            True               True           True          True
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
def check_int(value):
    try:
        int(value)
        return np.nan
    except ValueError:
        return value

# %%
df['word_freq_make'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_make, dtype: float64)

# %%
df['word_freq_all'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_all, dtype: float64)

# %%
df['word_freq_1999'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_1999, dtype: float64)

# %%
df['word_freq_over'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_over, dtype: float64)

# %%
df['word_freq_remove'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_remove, dtype: float64)

# %%
df['word_freq_mail'].apply(check_int).dropna()
# Out:
# Series([], Name: word_freq_mail, dtype: float64)

# %%
df.nunique()
# Out:
# word_freq_make                 142
# word_freq_address              171
# word_freq_all                  214
# word_freq_3d                    43
# word_freq_our                  255
# word_freq_over                 141
# word_freq_remove               173
# word_freq_internet             170
# word_freq_order                144
# word_freq_mail                 245
# word_freq_receive              113
# word_freq_will                 316
# word_freq_people               158
# word_freq_report               133
# word_freq_addresses            118
# word_freq_free                 253
# word_freq_business             197
# word_freq_email                229
# word_freq_you                  575
# word_freq_credit               148
# word_freq_your                 401
# word_freq_font                  99
# word_freq_000                  164
# word_freq_money                143
# word_freq_hp                   395
# word_freq_hpl                  281
# word_freq_george               240
# ...

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# word_freq_make                0.0
# word_freq_address             0.0
# word_freq_all                 0.0
# word_freq_3d                  0.0
# word_freq_our                 0.0
# word_freq_over                0.0
# word_freq_remove              0.0
# word_freq_internet            0.0
# word_freq_order               0.0
# word_freq_mail                0.0
# word_freq_receive             0.0
# word_freq_will                0.0
# word_freq_people              0.0
# word_freq_report              0.0
# word_freq_addresses           0.0
# word_freq_free                0.0
# word_freq_business            0.0
# word_freq_email               0.0
# word_freq_you                 0.0
# word_freq_credit              0.0
# word_freq_your                0.0
# word_freq_font                0.0
# word_freq_000                 0.0
# word_freq_money               0.0
# word_freq_hp                  0.0
# word_freq_hpl                 0.0
# word_freq_george              0.0
# ...

# %%
# Remove word_freq_000   column from data
df = df.drop(['word_freq_000'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
# Remove word_freq_650   column from data
df = df.drop(['word_freq_650'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
# Remove word_freq_857   column from data
df = df.drop(['word_freq_857'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
# Remove word_freq_415   column from data
df = df.drop(['word_freq_415'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
# Remove word_freq_85  column from data
df = df.drop(['word_freq_85'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
df['word_freq_make'] = df['word_freq_make'].astype(str)  # Ensure the column contains strings
df['capital_run_length_total'] = df['word_freq_make'].str.split().str.get(0)

# %%
df
# Out:
#      word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.0               0.64           0.64           0.0
# 1              0.21               0.28           0.50           0.0
# 2              0.06               0.00           0.71           0.0
# 3               0.0               0.00           0.00           0.0
# 4               0.0               0.00           0.00           0.0
# ...             ...                ...            ...           ...
# 4596           0.31               0.00           0.62           0.0
# 4597            0.0               0.00           0.00           0.0
# 4598            0.3               0.00           0.30           0.0
# 4599           0.96               0.00           0.00           0.0
# 4600            0.0               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# ...

# %%
print(df.word_freq_make.unique())
# Out:
# ['0.0' '0.21' '0.06' '0.15' '0.05' '1.17' '0.3' '0.18' '0.49' '0.46'
#  '0.73' '0.23' '0.12' '0.66' '0.75' '0.47' '0.59' '1.24' '0.5' '0.16'
#  '0.41' '1.0' '0.36' '0.39' '0.67' '0.42' '0.14' '0.62' '0.52' '0.17'
#  '0.44' '0.34' '0.43' '2.12' '0.54' '0.53' '0.51' '0.45' '0.22' '0.07'
#  '1.03' '0.26' '0.19' '0.84' '0.08' '0.48' '0.8' '0.58' '0.25' '0.4' '0.1'
#  '1.63' '0.35' '0.64' '0.63' '0.65' '0.2' '0.6' '0.76' '0.11' '1.05'
#  '0.29' '0.33' '0.27' '0.31' '0.09' '0.32' '0.57' '0.9' '0.28' '0.56'
#  '2.43' '1.18' '0.13' '2.32' '0.68' '0.79' '1.26' '0.89' '0.7' '0.82'
#  '0.87' '0.24' '0.95' '0.93' '0.98' '1.01' '0.72' '0.71' '1.23' '2.35'
#  '0.78' '0.38' '0.74' '1.36' '1.47' '0.69' '1.06' '1.61' '1.04' '0.37'
#  '1.19' '1.44' '0.61' '0.86' '0.77' '0.99' '0.85' '4.54' '0.96' '0.02'
#  '1.14' '0.81' '1.02' '1.11' '2.77' '0.01' '2.0' '0.04' '0.03' '1.09'
#  '0.97' '1.16' '2.27' '1.07' '3.94' '1.75' '3.03' '0.83' '0.55' '1.12'
# ...

# %% [markdown]
# # STASTICTS

# %%
#mean of the dataset
df.mean()
# Out:
# word_freq_address              0.213015
# word_freq_all                  0.280656
# word_freq_3d                   0.065425
# word_freq_our                  0.312223
# word_freq_over                 0.095901
# word_freq_remove               0.114208
# word_freq_internet             0.105295
# word_freq_order                0.090067
# word_freq_mail                 0.239413
# word_freq_receive              0.059824
# word_freq_will                 0.541702
# word_freq_people               0.093930
# word_freq_report               0.058626
# word_freq_addresses            0.049205
# word_freq_free                 0.248848
# word_freq_business             0.142586
# word_freq_email                0.184745
# word_freq_you                  1.662100
# word_freq_credit               0.085577
# word_freq_your                 0.809761
# word_freq_font                 0.121202
# word_freq_money                0.094269
# word_freq_hp                   0.549504
# ...

# %%
#mode of the word_freq_all
df["word_freq_all"].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
#mode of the dataset
df.mode()
# Out:
#   word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.0                0.0            0.0           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0            0.0             0.0               0.0                 0.0
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0              0.0             0.0  ...          0.0          0.0
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_hash  \
# 0          0.0          0.0          0.0             0.0
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                         1.0                           1
#
#    capital_run_length_total  spam
# 0                       0.0     0
#
# [1 rows x 53 columns]

# %%
#median of the dataset
df.median()
# Out:
# word_freq_make                 0.000
# word_freq_address              0.000
# word_freq_all                  0.000
# word_freq_3d                   0.000
# word_freq_our                  0.000
# word_freq_over                 0.000
# word_freq_remove               0.000
# word_freq_internet             0.000
# word_freq_order                0.000
# word_freq_mail                 0.000
# word_freq_receive              0.000
# word_freq_will                 0.100
# word_freq_people               0.000
# word_freq_report               0.000
# word_freq_addresses            0.000
# word_freq_free                 0.000
# word_freq_business             0.000
# word_freq_email                0.000
# word_freq_you                  1.310
# word_freq_credit               0.000
# word_freq_your                 0.220
# word_freq_font                 0.000
# word_freq_money                0.000
# word_freq_hp                   0.000
# word_freq_hpl                  0.000
# ...

# %%
#Finding Max
Maximum = max(df["capital_run_length_average"])
# Finding Min
Minimum = min(df["capital_run_length_average"])
 
# Difference Of Max and Min
Range = Maximum-Minimum    
print("Maximum = {}, Minimum = {} and Range = {}".format(
    Maximum, Minimum, Range))
# Out:
# Maximum = 1102.5, Minimum = 1.0 and Range = 1101.5

# %%
#Finding Max
Maximum = max(df["word_freq_you"])
# Finding Min
Minimum = min(df["word_freq_you"])
 
# Difference Of Max and Min
Range = Maximum-Minimum    
print("Maximum = {}, Minimum = {} and Range = {}".format(
    Maximum, Minimum, Range))
# Out:
# Maximum = 18.75, Minimum = 0.0 and Range = 18.75

# %%
# importing statistics module
from statistics import variance
 
# importing fractions as parameter values
from fractions import Fraction as fr

# %%
# Print the variance of each samples in dataset
print("Variance of Sample1 is % s " % (variance(df["word_freq_you"])))
# Out:
# Variance of Sample1 is 3.1523315909584877

# %%
# Print the variance of each samples in dataset
print("Variance of Sample1 is % s " % (variance(df["word_freq_all"])))
# Out:
# Variance of Sample1 is 0.2541600473337554

# %%
# Print the variance of each samples
print("Variance of Sample1 is % s " % (variance(df["word_freq_3d"])))
# Out:
# Variance of Sample1 is 1.9464473465881709

# %%
# Print the variance of each samples in dataset
print("Variance of Sample1 is % s " % (variance(df["char_freq_$"])))
# Out:
# Variance of Sample1 is 0.06045796350301919

# %%
# Print the variance of each samples in dataset
print("Variance of Sample1 is % s " % (variance(df["char_freq_["])))
# Out:
# Variance of Sample1 is 0.011967083113500846

# %%
# importing the statistics module
from statistics import stdev

# %%
# Print the standard deviation of  observations in dataset
print("The Standard Deviation of Sample1 is % s"
      % (stdev(df["char_freq_$"])))
# Out:
# The Standard Deviation of Sample1 is 0.2458820113449115

# %%
# Print the standard deviation of  observations in dataset
print("The Standard Deviation of Sample1 is % s"
      % (stdev(df["capital_run_length_average"])))
# Out:
# The Standard Deviation of Sample1 is 31.729448740210604

# %%
# Print the standard deviation of  observations in dataset
print("The Standard Deviation of Sample1 is % s"
      % (stdev(df["word_freq_our"])))
# Out:
# The Standard Deviation of Sample1 is 0.672512769284666

# %%
# Print the standard deviation of  observations in dataset
print("The Standard Deviation of Sample1 is % s"
      % (stdev(df["word_freq_3d"])))
# Out:
# The Standard Deviation of Sample1 is 1.3951513704928835

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Scatter plot

# %%
import matplotlib.pyplot as plt

# %%
# Scatter plot with word_freq_address  against spam
plt.scatter(df['word_freq_address'], df['spam'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('word_freq_address')
plt.ylabel('Spam')
plt.colorbar() 
plt.show()

# %%
# Scatter plot with word_freq_all  word_freq_table
plt.scatter(df['word_freq_all'], df['word_freq_table'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('word_freq_all')
plt.ylabel('word_freq_table')
plt.colorbar()
plt.show()

# %%
# Scatter plot with word_freq_1999  word_freq_3d
plt.scatter(df['word_freq_1999'], df['word_freq_3d'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('word_freq_all')
plt.ylabel('word_freq_3d')
plt.colorbar() 
plt.show()

# %%
# Scatter plot with word_freq_1999  word_freq_table
plt.scatter(df['word_freq_direct'], df['char_freq_hash'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('word_freq_direct')
plt.ylabel('char_freq_hash ')
plt.colorbar()
plt.show()

# %%
# Scatter plot with capital_run_length_total and capital_run_length_average
plt.scatter(df['capital_run_length_total'], df['capital_run_length_average'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('capital_run_length_total')
plt.ylabel('capital_run_length_average')
 
plt.show()

# %%
# Scatter plot with word_freq_project and word_freq_conference
plt.scatter(df['word_freq_project'], df['word_freq_conference'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('word_freq_project')
plt.ylabel('word_freq_conference')
plt.colorbar() 
plt.show()

# %% [markdown]
# ## Histogram

# %%
#importing the packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#histplot for spam
sns.histplot(x='spam',data=df,binwidth=3)
plt.title("spam HistoPlot")
plt.show()

# %%
#histplot for  word_freq_original
sns.histplot(x='word_freq_original',data=df,binwidth=3)
plt.title("word_freq_original HistoPlot")
plt.show()

# %%
#histplot for  capital_run_length_average
sns.histplot(x='capital_run_length_average',data=df,binwidth=3)
plt.title("capital_run_length_average HistoPlot")
plt.show()

# %%
#histplot for  word_freq_address
sns.histplot(x='word_freq_address',data=df,binwidth=3)
plt.title("word_freq_address HistoPlot")
plt.show()

# %%
#histplot for  word_freq_technology 
sns.histplot(x='word_freq_technology',data=df,binwidth=3)
plt.title("word_freq_technology  HistoPlot")
plt.show()

# %%
#histplot for  word_freq_telnet  
sns.histplot(x='word_freq_telnet',data=df,binwidth=3)
plt.title("word_freq_telnet   HistoPlot")
plt.show()

# %%
#histplot for  char_freq_[  
sns.histplot(x='char_freq_[',data=df,binwidth=3)
plt.title("char_freq_[   HistoPlot")
plt.show()

# %%
#histplot for  char_freq_$  
sns.histplot(x='char_freq_$',data=df,binwidth=3)
plt.title("char_freq_[   HistoPlot")
plt.show()

# %%
#histplot for  capital_run_length_longest  
sns.histplot(x='capital_run_length_longest',data=df,binwidth=3)
plt.title("capital_run_length_longest  HistoPlot")
plt.show()

# %% [markdown]
# ## BOXPLOT

# %%
#boxplot between word_freq_1999 and word_freq_edu
sns.boxplot( x="word_freq_1999", y='word_freq_edu', data=df )
plt.title("Boxplot")
plt.show()

# %%
#boxplot between word_freq_1999 and word_freq_edu
sns.boxplot( x="word_freq_1999", y='word_freq_edu', data=df )
plt.title("Boxplot")
plt.show()

# %%
#boxplot between word_freq_money and word_freq_credit
sns.boxplot( x="word_freq_money", y='word_freq_credit', data=df )
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ## BARCHART

# %%
# Bar chart with day against tip
plt.bar(df['word_freq_hp'], df['word_freq_technology'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('word_freq_hp')
plt.ylabel('word_freq_technology')
 
# Adding the legends
plt.show()

# %%
# Bar chart with day against tip
plt.bar(df['word_freq_george'], df['word_freq_lab'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('word_freq_george')
plt.ylabel('word_freq_lab')
 
# Adding the legends
plt.show()

# %%
# Bar chart with day against tip
plt.bar(df['word_freq_data'], df['char_freq_$'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('word_freq_data')
plt.ylabel('char_freq_$')
 
# Adding the legends
plt.show()

# %%
# Bar chart with day against tip
plt.bar(df['capital_run_length_total'], df['word_freq_pm'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('capital_run_length_total')
plt.ylabel('word_freq_pm')
 
# Adding the legends
plt.show()

# %% [markdown]
# ## LINECHART

# %%
#line chart
plt.plot(df['char_freq_$'])
plt.plot(df['char_freq_hash'])
plt.title("LINE CHART FOR char_freq_$ AND char_freq_hash")
plt.xlabel('char_freq_$')
plt.ylabel('char_freq_hash')
plt.show()

# %%
#line chart
plt.plot(df['word_freq_original'])
plt.plot(df['word_freq_money'])
plt.title("LINE CHART FOR word_freq_original AND word_freq_money")
plt.xlabel('word_freq_original')
plt.ylabel('word_freq_money')
plt.show()

# %%
#line chart
plt.plot(df['capital_run_length_longest'])
plt.plot(df['spam'])
plt.title("LINE CHART FOR capital_run_length_longest AND spam")
plt.xlabel('capital_run_length_longest')
plt.ylabel('spam')
plt.show()

# %% [markdown]
# ### BAR PLOT

# %%
#bar plot
sns.barplot(x=df["word_freq_all"],y=df["char_freq_("],hue=df["word_freq_make"])
plt.title("BAR PLOT")
plt.show()

# %%
#bar plot
sns.barplot(x=df["spam"],y=df["word_freq_original"],hue=df["word_freq_edu"])
plt.title("BAR PLOT")
plt.show()

# %%
#bar plot
sns.barplot(x=df["word_freq_order"],y=df["word_freq_receive"],hue=df["word_freq_our"])
plt.title("BAR PLOT")
plt.show()

# %% [markdown]
# ## FIGURE

# %%
#figure
plt.figure(figsize=(20,20))
plt.title("word_freq_your")
plt.hist(df["word_freq_your"],bins=np.arange(1,10,0.5),color="skyblue")
# Out:
# (array([590., 297., 208., 134., 107.,  54.,  26.,  14.,  33.,   5.,   3.,
#           7.,   3.,   0.,  11.,   1.,   1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ,
#         7.5, 8. , 8.5, 9. , 9.5]),
#  <BarContainer object of 17 artists>)

# %%
#figure
plt.figure(figsize=(20,20))
plt.title("word_freq_font")
plt.hist(df["word_freq_font"],bins=np.arange(1,10,0.5),color="red")
# Out:
# (array([7., 9., 4., 4., 1., 2., 2., 1., 0., 2., 2., 3., 6., 2., 6., 5., 8.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ,
#         7.5, 8. , 8.5, 9. , 9.5]),
#  <BarContainer object of 17 artists>)

# %%
#figure
plt.figure(figsize=(20,20))
plt.title("word_freq_you")
plt.hist(df["word_freq_you"],bins=np.arange(1,10,0.5),color="yellow")
# Out:
# (array([468., 422., 423., 324., 280., 209., 175.,  81.,  54.,  42.,  24.,
#          21.,  19.,   9.,  12.,   4.,   4.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ,
#         7.5, 8. , 8.5, 9. , 9.5]),
#  <BarContainer object of 17 artists>)

# %% [markdown]
# ## COUNTPLOT

# %%
# count plot for capital_run_length_longest
sns.countplot(data=df,x="capital_run_length_longest")
plt.title("capital_run_length_longest")
plt.show()

# %%
# count plot for word_freq_3d
sns.countplot(data=df,x="word_freq_3d")
plt.title("word_freq_3d")
plt.show()

# %% [markdown]
# ## SCATTERPLOT

# %%
#scatter plot between word_freq_over and word_freq_free
sns.scatterplot(x='word_freq_over', y='word_freq_free', data=df,hue='word_freq_you')
plt.show()

# %%
#scatter plot between char_freq_$ and capital_run_length_longest
sns.scatterplot(x='char_freq_$', y='capital_run_length_longest', data=df,hue='spam')
plt.show()

# %%
#scatter plot between char_freq_$ and capital_run_length_longest
sns.scatterplot(x='word_freq_conference', y='word_freq_meeting', data=df,hue='word_freq_parts')
plt.show()

# %%
#scatter plot between word_freq_credit and word_freq_telnet
sns.scatterplot(x='word_freq_credit', y='word_freq_telnet', data=df,hue='word_freq_re')
plt.show()

# %% [markdown]
# ## Markdown

# %%
sns.lineplot(x='word_freq_hpl', y='word_freq_hp', data=df)
plt.show()

# %%
sns.lineplot(x='word_freq_direct', y='word_freq_remove', data=df)
plt.show()

# %%
sns.lineplot(x='word_freq_mail', y='word_freq_people', data=df)
plt.show()
